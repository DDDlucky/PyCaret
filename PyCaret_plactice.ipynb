# %% [markdown]
# <a href="https://colab.research.google.com/github/DDDlucky/PyCaret/blob/main/PyCaret_plactice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"https://toukei-lab.com/pycaret"

# %%
# !pip install pycaret

# %%
from pycaret.datasets import get_data
boston = get_data('boston')
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
from pycaret.regression import *
exp1 = setup(boston, target = 'medv')
# Out:
#                                Description             Value
# 0                               session_id              8985
# 1                                   Target              medv
# 2                            Original Data         (506, 14)
# 3                           Missing Values             False
# 4                         Numeric Features                11
# 5                     Categorical Features                 2
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (354, 21)
# 10                    Transformed Test Set         (152, 21)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
compare_models()
# Out:
#                                     Model     MAE       MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  2.1846    9.1270  2.9479  0.8963
# rf                Random Forest Regressor  2.2459   10.8129  3.2064  0.8764
# et                  Extra Trees Regressor  2.1324   10.3578  3.0897  0.8730
# lightgbm  Light Gradient Boosting Machine  2.3481   11.6802  3.3169  0.8602
# ada                    AdaBoost Regressor  2.7567   14.3097  3.7010  0.8318
# dt                Decision Tree Regressor  3.0803   22.3243  4.5279  0.7448
# lr                      Linear Regression  3.3628   23.8299  4.8286  0.7231
# ridge                    Ridge Regression  3.3282   23.9596  4.8419  0.7213
# br                         Bayesian Ridge  3.3068   24.4018  4.8854  0.7158
# lar                Least Angle Regression  3.4858   24.6666  4.9146  0.7133
# en                            Elastic Net  3.7691   30.1483  5.4586  0.6527
# ...

# %%
lightgbm = create_model('lightgbm')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     1.8682   6.2109  2.4922  0.9385  0.0946  0.0826
# 1     2.6495  18.0213  4.2451  0.8110  0.2197  0.1631
# 2     2.3261   8.7210  2.9531  0.9151  0.1454  0.1161
# 3     1.9452   5.5192  2.3493  0.9315  0.0978  0.0862
# 4     2.3234  10.4253  3.2288  0.8738  0.2052  0.1605
# 5     3.1613  23.1548  4.8119  0.7195  0.2249  0.1726
# 6     2.2719   9.5637  3.0925  0.9165  0.1252  0.1050
# 7     2.1632   7.4660  2.7324  0.9091  0.1450  0.1073
# 8     2.5484  19.8020  4.4499  0.6823  0.1831  0.1238
# 9     2.2240   7.9174  2.8138  0.9042  0.1320  0.1107
# Mean  2.3481  11.6802  3.3169  0.8602  0.1573  0.1228
# SD    0.3523   5.9367  0.8235  0.0870  0.0457  0.0304

# %%
predict_model = predict_model(lightgbm)
# Out:
#                              Model     MAE      MSE  ...      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  2.6903  16.6433  ...  0.7677  0.1806  0.1392
#
# [1 rows x 7 columns]

# %%
lgbm_tune = tune_model(lightgbm)
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.0403   7.4670  2.7326  0.9261  0.1104  0.0941
# 1     2.3434   9.6804  3.1113  0.8985  0.1630  0.1264
# 2     2.1460   7.5855  2.7542  0.9261  0.1444  0.1105
# 3     1.5088   3.4867  1.8673  0.9567  0.0983  0.0785
# 4     1.7281   5.9857  2.4466  0.9275  0.1358  0.1036
# 5     2.9985  26.1539  5.1141  0.6832  0.2212  0.1544
# 6     2.1809   6.9297  2.6324  0.9395  0.1192  0.1058
# 7     1.9849   5.7063  2.3888  0.9305  0.1342  0.1107
# 8     2.0728  12.4225  3.5246  0.8007  0.1463  0.0981
# 9     2.0798   8.4087  2.8998  0.8983  0.1083  0.0932
# Mean  2.1084   9.3826  2.9472  0.8887  0.1381  0.1075
# SD    0.3715   6.0356  0.8348  0.0796  0.0336  0.0198
